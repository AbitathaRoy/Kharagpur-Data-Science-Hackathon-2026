# %%
import sys
import os
import json
parent_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))
if parent_dir not in sys.path:
    sys.path.append(parent_dir)

from extraction.caption_claims import extract_caption_claims

# %%
result= extract_caption_claims(
    "His childhood poverty made him distrust the elite."
    )
result
# Out:
# CaptionClaims(events=[EventClaim(description='childhood poverty', time_scope='childhood')], traits=[TraitClaim(trait='distrust of the elite', time_scope='acquired')], causal_links=[CausalLink(cause='childhood poverty', effect='distrust of the elite', confidence='implied')], assumptions=['the elite are responsible for or connected to his poverty'])

# %%
result= extract_caption_claims(
    "Growing up neglected, he later avoided emotional intimacy."
    )
result
# Out:
# CaptionClaims(events=[EventClaim(description='grew up neglected', time_scope='childhood')], traits=[TraitClaim(trait='avoided emotional intimacy', time_scope='acquired')], causal_links=[CausalLink(cause='grew up neglected', effect='avoided emotional intimacy', confidence='implied')], assumptions=['neglect during childhood can influence adult behavior'])

# %%
result= extract_caption_claims(
    "He grew up in Paris and became a doctor."
    )
result
# Out:
# CaptionClaims(events=[EventClaim(description='grew up in Paris', time_scope='childhood'), EventClaim(description='became a doctor', time_scope='adulthood')], traits=[TraitClaim(trait='doctor', time_scope='acquired')], causal_links=[CausalLink(cause='grew up in Paris', effect='became a doctor', confidence='implied')], assumptions=['Paris is a location where one can grow up and become a doctor'])

# %%
result= extract_caption_claims(
    "After the war, he became bitter toward authority."
    )
result
# Out:
# CaptionClaims(events=[EventClaim(description='a war', time_scope='adulthood')], traits=[TraitClaim(trait='bitterness toward authority', time_scope='acquired')], causal_links=[CausalLink(cause='the war', effect='bitterness toward authority', confidence='implied')], assumptions=['there was a war', 'the character was affected by the war'])

# %%
result= extract_caption_claims(
    "He had a difficult childhood."
    )
result
# Out:
# CaptionClaims(events=[EventClaim(description='had a difficult childhood', time_scope='childhood')], traits=[TraitClaim(trait='difficult childhood', time_scope='stable')], causal_links=[], assumptions=[])
